# %%
import os
import os.path as osp
import cv2
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
path = 'E:\\test_minsung\\thermal\\images_resized'
# path = 'E:\\test_minsung\\output'
path = osp.join(path, 'img_00003.tiff')
img = Image.open(path)
print(img.height, img.width)
print(type(img))
plt.imshow(img)

image = cv2.imread(path)

print(image)
print(image.shape)
# Out:
# 1332 1776
# <class 'PIL.TiffImagePlugin.TiffImageFile'>
# None
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 12
#       9 image = cv2.imread(path)
#      11 print(image)
# ---> 12 print(image.shape)
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
tif_path = 'E:\\test_minsung\\output\\orthophoto_combined_thermal.tif'
tif = cv2.imread(tif_path, cv2.IMREAD_UNCHANGED)
